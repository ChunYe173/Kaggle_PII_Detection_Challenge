# %%
import openai
import json
import pandas as pd
import os

# %%
json_file_path = r'C:\Users\cytan\Downloads\pii-detection-removal-from-educational-data\train.json'

# %%
df = pd.read_json(json_file_path)
df.head()
# Out:
#    document                                          full_text  \
# 0         7  Design Thinking for innovation reflexion-Avril...
# 1        10  Diego Estrada\n\nDesign Thinking Assignment\n\...
# 2        16  Reporting process\n\nby Gilberto Gamboa\n\nCha...
# 3        20  Design Thinking for Innovation\n\nSindy Samaca...
# 4        56  Assignment:  Visualization Reflection  Submitt...
#
#                                               tokens  \
# 0  [Design, Thinking, for, innovation, reflexion,...
# 1  [Diego, Estrada, \n\n, Design, Thinking, Assig...
# 2  [Reporting, process, \n\n, by, Gilberto, Gambo...
# 3  [Design, Thinking, for, Innovation, \n\n, Sind...
# 4  [Assignment, :,   , Visualization,  , Reflecti...
#
#                                  trailing_whitespace  \
# 0  [True, True, True, True, False, False, True, F...
# 1  [True, False, False, True, True, False, False,...
# 2  [True, False, False, True, True, False, False,...
# ...

# %%
document_key = 'document'
text_key = 'full_text'  # Replace with the actual key for text
tokens_key = 'tokens'  # Replace with the actual key for tokens
whitespace_key = 'trailing_whitespace'
pii_label_key = 'labels'  # Replace with the actual key for PII_label

# %%
with open(json_file_path, 'r') as json_file:
    data = json.load(json_file)

# %%
for i in range(5):
    print(data[i])

print(type(data))
# Out:
# {'document': 7, 'full_text': "Design Thinking for innovation reflexion-Avril 2021-Nathalie Sylla\n\nChallenge & selection\n\nThe tool I use to help all stakeholders finding their way through the complexity of a project is the  mind map.\n\nWhat exactly is a mind map? According to the definition of Buzan T. and Buzan B. (1999, Dessine-moi  l'intelligence. Paris: Les Éditions d'Organisation.), the mind map (or heuristic diagram) is a graphic  representation technique that follows the natural functioning of the mind and allows the brain's  potential to be released. Cf Annex1\n\nThis tool has many advantages:\n\n•  It is accessible to all and does not require significant material investment and can be done  quickly\n\n•  It is scalable\n\n•  It allows categorization and linking of information\n\n•  It can be applied to any type of situation: notetaking, problem solving, analysis, creation of  new ideas\n\n•  It is suitable for all people and is easy to learn\n\n•  It is fun and encourage
# ...

# %%
from openai import OpenAI

client = OpenAI(
  api_key='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',  # this is also the default, it can be omitted
)

# %%
generated_text = []

for i, entry in enumerate (data):
    if i < 5:    
        input_text = entry[text_key]
        prompt = f'Take this dictionary {entry} as example and generate a similar one'
        response = client.completions.create(model='gpt-3.5-turbo', prompt=prompt)
        generated_text.append(response)
    else:
        break
print(generated_text[0])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-39-602ffd883e88> in <module>
#       5         input_text = entry[text_key]
#       6         prompt = f'Take this dictionary {entry} as example and generate a similar one'
# ----> 7         response = client.completions.create(model='gpt-3.5-turbo', prompt=prompt)
#       8         generated_text.append(response)
#       9     else:
#
# d:\anaconda3\lib\site-packages\openai\_utils\_utils.py in wrapper(*args, **kwargs)
#     269                         msg = f"Missing required argument: {quote(missing[0])}"
#     270                 raise TypeError(msg)
# --> 271             return func(*args, **kwargs)
#     272
#     273         return wrapper  # type: ignore
#
# ...
